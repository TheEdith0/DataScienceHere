# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# %%
#loads data
(x_train,y_train),(x_test,y_test)=mnist.load_data()

#normalizing(0,1)
x_train=x_train/255
x_test=x_test/255

#one hot encoding
y_train=to_categorical(y_train,10)
y_test=to_categorical(y_test,10)

# %%
#model building
model=Sequential([
    Flatten(input_shape=(28,28)),
    Dense(128,activation="relu"),
    Dense(10,activation="softmax")
])

#compiling model
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)
#training model
model.fit(x_train,y_train,epochs=9,batch_size=32)
# Out:
# Epoch 1/9
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 834us/step - accuracy: 0.9265 - loss: 0.2578
# Epoch 2/9
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 823us/step - accuracy: 0.9657 - loss: 0.1139
# Epoch 3/9
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 878us/step - accuracy: 0.9763 - loss: 0.0794
# Epoch 4/9
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 836us/step - accuracy: 0.9810 - loss: 0.0605
# Epoch 5/9
#  236/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 854us/step - accuracy: 0.9876 - loss: 0.0404

# %%
#evaluating about model
test_loss,test_acc=model.evaluate(x_test,y_test)
print(f"The accuracy of the model is {test_acc:.4f} ")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - accuracy: 0.9743 - loss: 0.0845
# The accuracy of the model is 0.9743
