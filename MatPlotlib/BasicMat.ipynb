# %%
#Used to visualize stats & patterns
import matplotlib.pyplot as plt 
plt.plot([1,2,3],[1,2,3])#([x-axis point],[y-axis points]) # kind of a list
plt.show()

# %%
#Virat Kohli Data:
year=list(range(2008,2027))
Virat=[31.8,54.16,47.38,47.62,68.4,52.83,58.55,36.64,92.37,76.84,133.55,59.86,47.88,43.00,27.45,72.47,19.33,65.1,80]
plt.plot(year,Virat)
plt.xlabel("Year")
plt.ylabel("Average Runs")
plt.title("Virat Kohli's Avg. runs per year")
# Out:
# Text(0.5, 1.0, "Virat Kohli's Avg. runs per year")

# %%
year=list(range(2008,2027))
Virat=[31.8,54.16,47.38,47.62,68.4,52.83,58.55,36.64,92.37,76.84,133.55,59.86,47.88,43.00,27.45,72.47,19.33,65.1,80]
Rohit=[25.33,25.50,38.76,55.54,12.92,52.00,52.54,50.93,62.66,71.83,73.57,57.30,57.00,30.00,41.50,52.29,52.33,50.00,20.33]
plt.plot(year,Virat,label="Virat Kohli")
plt.plot(year,Rohit,label="Rohit Sharma")
plt.xlabel("Year")
plt.ylabel("Average Runs")
plt.title("Average runs per year")
plt.legend()
plt.show()
#Can also use more than 2 comaparisons

# %%
plt.plot(year,Virat,"ro-",label="Virat Kohli") #'[color][marker][linestyle]'
plt.plot(year,Rohit,"g^:",label="Rohit Sharma")
plt.xlabel("Year")
plt.ylabel("Average Runs")
plt.title("Average runs per year")
plt.legend()
plt.show()

# %%
plt.plot(year,Virat,color="orange",linestyle="-") #Another way of setting color and linestyle
plt.plot(year,Rohit,color="green",linestyle="-.",linewidth=3) #linewidth can also be set
plt.xlabel("Year")
plt.ylabel("Average Runs")
plt.title("Average runs per year")
plt.tight_layout()# difference show shown better in .py file
plt.grid(True)# grids will be shown
plt.legend(["Virat Kohli","Rohit Sharma"]) #you can also label in legend instead of plot 
plt.show()

# %%
#there are different sytles to plot a graph 
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("grayscale")
plt.plot(year,Virat,color="orange",linestyle="-") #Another way of setting color and linestyle
plt.plot(year,Rohit,color="green",linestyle="-.",linewidth=3) #linewidth can also be set
plt.xlabel("Year")
plt.ylabel("Average Runs")
plt.title("Average runs per year")
plt.tight_layout() # difference show shown better in .py file
plt.grid(True) # grids will be shown
plt.legend(["Virat Kohli","Rohit Sharma"]) # you can also label in legend instead of plot 
plt.show()

# %%
#Now you think as we can plot data why we need to clean and take some patterns outoff it reason is that it is hard for human to understand so much of plots in a single graphh

# %%
import numpy as np

for i in range(4):
    plt.plot(np.random.rand(100), linewidth=1)

plt.title("Too Much Data Can Be Confusing!")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html 
#important site for styles
