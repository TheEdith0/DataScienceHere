# %% [raw]
# import json

# %%
def load_data(filename):
    with open(filename,"r") as file:
        data=json.load(file)
        return data

# %%
data=load_data("Data.json")
print(data)
# Out:
# {'users': [{'id': 1, 'name': 'Amit', 'friends': [2, 3], 'liked_pages': [101]}, {'id': 2, 'name': 'Priya', 'friends': [1, 4], 'liked_pages': [102]}, {'id': 3, 'name': 'Rahul', 'friends': [1], 'liked_pages': [101, 103]}, {'id': 4, 'name': 'Sara', 'friends': [2], 'liked_pages': [104]}], 'pages': [{'id': 101, 'name': 'Python Developers'}, {'id': 102, 'name': 'Data Science Enthusiasts'}, {'id': 103, 'name': 'AI & ML Community'}, {'id': 104, 'name': 'Web Dev Hub'}]}

# %%
def display_info(data):
    for user in data["users"]:
        print(f"{user["id"]}. {user["name"]} has following friends:{user["friends"]} and has liked the pages {user["liked_pages"]}")
    print("\nInformation of pages:")
    for page in data["pages"]:
        print(f"Page no.{page["id"]}. is for {page["name"]}")

# %%
info=load_data("Data.json")
display_info(info)
# Out:
# 1. Amit has following friends:[2, 3] and has liked the pages [101]
# 2. Priya has following friends:[1, 4] and has liked the pages [102]
# 3. Rahul has following friends:[1] and has liked the pages [101, 103]
# 4. Sara has following friends:[2] and has liked the pages [104]
#
# Information of pages:
# Page no.101. is for Python Developers
# Page no.102. is for Data Science Enthusiasts
# Page no.103. is for AI & ML Community
# Page no.104. is for Web Dev Hub
