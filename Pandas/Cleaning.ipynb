# %%
import pandas as pd
df=pd.read_csv("data_cleaning_sample.csv")
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        delhi      M    charlie@example  20-07-2021

# %%
df["Age"].isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# 8     True
# Name: Age, dtype: bool

# %%
df.isnull().sum()
# Out:
# Name         1
# Age          3
# City         0
# Gender       0
# Email        0
# Join Date    1
# dtype: int64

# %%
df["Age"].fillna(df["Age"].mean())
#to implement this change assign it df["Age"]=*****
# Out:
# 0    25.000000
# 1    25.833333
# 2    30.000000
# 3    25.833333
# 4    22.000000
# 5    28.000000
# 6    25.000000
# 7    25.000000
# 8    25.833333
# Name: Age, dtype: float64

# %%
df.loc[1,"Age"]=df["Age"].mean()
#this can change a single element

# %%
df
# Out:
#       Name        Age         City Gender              Email   Join Date
# 0    Alice  25.000000     New York      F  alice@example.com  01-05-2021
# 1  Charlie  25.833333        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.000000  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie        NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.000000       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.000000        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.000000     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.000000     New York      F  alice@example.com  01-05-2021
# 8  Charlie        NaN        delhi      M    charlie@example  20-07-2021

# %%
df.dropna()#Returns datafame containing row with no NaNs
#to assign : df=df.dropna()
# Out:
#       Name        Age         City Gender              Email   Join Date
# 0    Alice  25.000000     New York      F  alice@example.com  01-05-2021
# 1  Charlie  25.833333        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.000000  Los Angeles      M    bob@example.com  15-06-2020
# 4    David  22.000000       Mumbai      M  david@example.com  12-11-2019
# 6    Alice  25.000000     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.000000     New York      F  alice@example.com  01-05-2021

# %%
df.dropna(axis=1)#returns Dataframe having coulmn with no NaN
# Out:
#           City Gender              Email
# 0     New York      F  alice@example.com
# 1        Delhi      M    charlie@example
# 2  Los Angeles      M    bob@example.com
# 3        Delhi      M    charlie@example
# 4       Mumbai      M  david@example.com
# 5        Delhi      F     eve@domain.com
# 6     New York      F  alice@example.com
# 7     New York      F  alice@example.com
# 8        delhi      M    charlie@example

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7     True
# 8    False
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#       Name        Age         City Gender              Email   Join Date
# 0    Alice  25.000000     New York      F  alice@example.com  01-05-2021
# 1  Charlie  25.833333        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.000000  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie        NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.000000       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.000000        Delhi      F     eve@domain.com         NaN
# 8  Charlie        NaN        delhi      M    charlie@example  20-07-2021

# %%
df.duplicated(subset=["Name","Age"])
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
df.drop_duplicates(subset=["Gender"])
# Out:
#       Name        Age      City Gender              Email   Join Date
# 0    Alice  25.000000  New York      F  alice@example.com  01-05-2021
# 1  Charlie  25.833333     Delhi      M    charlie@example  20-07-2021

# %%
df
# Out:
#       Name        Age         City Gender              Email   Join Date
# 0    Alice  25.000000     New York      F  alice@example.com  01-05-2021
# 1  Charlie  25.833333        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.000000  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie        NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.000000       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.000000        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.000000     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.000000     New York      F  alice@example.com  01-05-2021
# 8  Charlie        NaN        delhi      M    charlie@example  20-07-2021

# %%
df["Name"].str.lower()
# Out:
# 0      alice
# 1    charlie
# 2        bob
# 3    charlie
# 4      david
# 5        NaN
# 6      alice
# 7      alice
# 8    charlie
# Name: Name, dtype: object

# %%
df["City"].str.contains("delhi",case=False)
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7    False
# 8     True
# Name: City, dtype: bool

# %%
df["Email"].str.split("@")
# Out:
# 0    [alice, example.com]
# 1      [charlie, example]
# 2      [bob, example.com]
# 3      [charlie, example]
# 4    [david, example.com]
# 5       [eve, domain.com]
# 6    [alice, example.com]
# 7    [alice, example.com]
# 8      [charlie, example]
# Name: Email, dtype: object

# %%
df2=df.dropna().copy()
df2["Age"]=df2["Age"].astype(int)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       6 non-null      object
#  1   Age        6 non-null      int64
#  2   City       6 non-null      object
#  3   Gender     6 non-null      object
#  4   Email      6 non-null      object
#  5   Join Date  6 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 336.0+ bytes

# %%
df["Join Date"] = pd.to_datetime(df["Join Date"], dayfirst=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       8 non-null      object
#  1   Age        7 non-null      float64
#  2   City       9 non-null      object
#  3   Gender     9 non-null      object
#  4   Email      9 non-null      object
#  5   Join Date  8 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 564.0+ bytes

# %%
df["Age Group"]=df["Age"].apply(lambda x:"Adult" if x>21 else "Minor")

# %%
df
# Out:
#       Name        Age         City Gender              Email  Join Date  \
# 0    Alice  25.000000     New York      F  alice@example.com 2021-05-01
# 1  Charlie  25.833333        Delhi      M    charlie@example 2021-07-20
# 2      Bob  30.000000  Los Angeles      M    bob@example.com 2020-06-15
# 3  Charlie        NaN        Delhi      M    charlie@example 2021-07-20
# 4    David  22.000000       Mumbai      M  david@example.com 2019-11-12
# 5      NaN  28.000000        Delhi      F     eve@domain.com        NaT
# 6    Alice  25.000000     New York      F  alice@example.com 2021-05-01
# 7    Alice  25.000000     New York      F  alice@example.com 2021-05-01
# 8  Charlie        NaN        delhi      M    charlie@example 2021-07-20
#
#   Age Group
# 0     Adult
# 1     Adult
# 2     Adult
# 3     Minor
# 4     Adult
# 5     Adult
# 6     Adult
# 7     Adult
# 8     Minor

# %%
df["Gender"]=df["Gender"].map({"M":"Male","F":"Female"})

# %%
df
# Out:
#       Name        Age         City  Gender              Email  Join Date  \
# 0    Alice  25.000000     New York  Female  alice@example.com 2021-05-01
# 1  Charlie  25.833333        Delhi    Male    charlie@example 2021-07-20
# 2      Bob  30.000000  Los Angeles    Male    bob@example.com 2020-06-15
# 3  Charlie        NaN        Delhi    Male    charlie@example 2021-07-20
# 4    David  22.000000       Mumbai    Male  david@example.com 2019-11-12
# 5      NaN  28.000000        Delhi  Female     eve@domain.com        NaT
# 6    Alice  25.000000     New York  Female  alice@example.com 2021-05-01
# 7    Alice  25.000000     New York  Female  alice@example.com 2021-05-01
# 8  Charlie        NaN        delhi    Male    charlie@example 2021-07-20
#
#   Age Group
# 0     Adult
# 1     Adult
# 2     Adult
# 3     Minor
# 4     Adult
# 5     Adult
# 6     Adult
# 7     Adult
# 8     Minor

# %%
df["City"]=df["City"].replace({"delhi":"Delhi","Mumbai":"Navi Mumbai"})

# %%
df
# Out:
#       Name        Age         City  Gender              Email  Join Date  \
# 0    Alice  25.000000     New York  Female  alice@example.com 2021-05-01
# 1  Charlie  25.833333        Delhi    Male    charlie@example 2021-07-20
# 2      Bob  30.000000  Los Angeles    Male    bob@example.com 2020-06-15
# 3  Charlie        NaN        Delhi    Male    charlie@example 2021-07-20
# 4    David  22.000000  Navi Mumbai    Male  david@example.com 2019-11-12
# 5      NaN  28.000000        Delhi  Female     eve@domain.com        NaT
# 6    Alice  25.000000     New York  Female  alice@example.com 2021-05-01
# 7    Alice  25.000000     New York  Female  alice@example.com 2021-05-01
# 8  Charlie        NaN        Delhi    Male    charlie@example 2021-07-20
#
#   Age Group
# 0     Adult
# 1     Adult
# 2     Adult
# 3     Minor
# 4     Adult
# 5     Adult
# 6     Adult
# 7     Adult
# 8     Minor
