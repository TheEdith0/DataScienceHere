# %%
import pandas as pd

# %%
s=pd.Series([97,0,100,98],index=["A","S","K","V"]) # default indexes are 0 1 2 3
print(s)
s.index=["Ashvin","Shikha","Keerti","Varsha"]
print(s)
# Out:
# A     97
# S      0
# K    100
# V     98
# dtype: int64
# Ashvin     97
# Shikha      0
# Keerti    100
# Varsha     98
# dtype: int64

# %%
#DataFrame
data={
    "Name":["Ashvin","Shikha","Keerti","Varsha"],
    "Marks":[97,0,100,98],
    "Result":["Pass","Fail","Pass","Pass"]
}
df=pd.DataFrame(data,)
print(df)
# Out:
#      Name  Marks Result
# 0  Ashvin     97   Pass
# 1  Shikha      0   Fail
# 2  Keerti    100   Pass
# 3  Varsha     98   Pass
