# %%
import pandas as pd
df=pd.read_csv("Data2.csv")

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df.sort_values("Year")
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df.sort_values(["Year","BoxOffice(INR Crore)"])
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 7       Hrithik Roshan                       War  2019           Action
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2=df.sort_values("Year",ascending=False)
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 2           Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2.iloc[2,0]
# Out:
# 'Kartik Aaryan'

# %%
df2.loc[2,"Actor"]
# Out:
# 'Aamir Khan'

# %%
df2.reset_index(drop=True)#these change won't apply to real one
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 2        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 3       Hrithik Roshan                       War  2019           Action
# 4         Akshay Kumar                Good Newwz  2019           Comedy
# 5        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 6        Ranveer Singh                 Padmaavat  2018       Historical
# 7   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 8        Rajkummar Rao                     Stree  2018    Horror Comedy
# 9          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11          Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2.sort_index()#use inplace =True for change in real one
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2.reset_index(drop=True,inplace=True)#inplace to chnage in real one 
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 2        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 3       Hrithik Roshan                       War  2019           Action
# 4         Akshay Kumar                Good Newwz  2019           Comedy
# 5        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 6        Ranveer Singh                 Padmaavat  2018       Historical
# 7   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 8        Rajkummar Rao                     Stree  2018    Horror Comedy
# 9          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11          Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2["Rank"]=df2["IMDb"].rank(ascending=False,method="dense")#method="dense" will return integer values ranking as default it is float
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 2        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 3       Hrithik Roshan                       War  2019           Action
# 4         Akshay Kumar                Good Newwz  2019           Comedy
# 5        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 6        Ranveer Singh                 Padmaavat  2018       Historical
# 7   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 8        Rajkummar Rao                     Stree  2018    Horror Comedy
# 9          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11          Aamir Khan                    Dangal  2016        Biography
#
# ...

# %%
df2.sort_values("Rank",inplace=True)

# %%
df2.reset_index(drop=True,inplace=True)
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0           Aamir Khan                    Dangal  2016        Biography
# 1   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 2        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Rajkummar Rao                     Stree  2018    Horror Comedy
# 4       Shah Rukh Khan                   Pathaan  2023           Action
# 5         Akshay Kumar                Good Newwz  2019           Comedy
# 6        Ranveer Singh                 Padmaavat  2018       Historical
# 7       Hrithik Roshan                       War  2019           Action
# 8         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 9          Salman Khan           Tiger Zinda Hai  2017           Action
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11       Ranbir Kapoor                Brahmastra  2022          Fantasy
#
# ...

# %%
df2.rename(columns={"Film":"Movie"},inplace=True)

# %%
df2.rename(index={11:12},inplace=True)

# %%
df2
# Out:
#                  Actor                     Movie  Year            Genre  \
# 0           Aamir Khan                    Dangal  2016        Biography
# 1   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 2        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Rajkummar Rao                     Stree  2018    Horror Comedy
# 4       Shah Rukh Khan                   Pathaan  2023           Action
# 5         Akshay Kumar                Good Newwz  2019           Comedy
# 6        Ranveer Singh                 Padmaavat  2018       Historical
# 7       Hrithik Roshan                       War  2019           Action
# 8         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 9          Salman Khan           Tiger Zinda Hai  2017           Action
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 12       Ranbir Kapoor                Brahmastra  2022          Fantasy
#
# ...

# %%
df2.index=["A","B","C","D","E","F","G","H","I","J","K","L"]

# %%
df2
# Out:
#                 Actor                     Movie  Year            Genre  \
# A          Aamir Khan                    Dangal  2016        Biography
# B  Ayushmann Khurrana                 Andhadhun  2018         Thriller
# C       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# D       Rajkummar Rao                     Stree  2018    Horror Comedy
# E      Shah Rukh Khan                   Pathaan  2023           Action
# F        Akshay Kumar                Good Newwz  2019           Comedy
# G       Ranveer Singh                 Padmaavat  2018       Historical
# H      Hrithik Roshan                       War  2019           Action
# I        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# J         Salman Khan           Tiger Zinda Hai  2017           Action
# K       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# L       Ranbir Kapoor                Brahmastra  2022          Fantasy
#
#    BoxOffice(INR Crore)  IMDb  Rank
# ...

# %%
cols=["Movie"]+[c for c in df2.columns if c!="Movie"]
df2=df2[cols]#this take Movie in front

# %%
df2
# Out:
#                       Movie               Actor  Year            Genre  \
# A                    Dangal          Aamir Khan  2016        Biography
# B                 Andhadhun  Ayushmann Khurrana  2018         Thriller
# C  Uri: The Surgical Strike       Vicky Kaushal  2019           Action
# D                     Stree       Rajkummar Rao  2018    Horror Comedy
# E                   Pathaan      Shah Rukh Khan  2023           Action
# F                Good Newwz        Akshay Kumar  2019           Comedy
# G                 Padmaavat       Ranveer Singh  2018       Historical
# H                       War      Hrithik Roshan  2019           Action
# I     Badrinath Ki Dulhania        Varun Dhawan  2017  Romantic Comedy
# J           Tiger Zinda Hai         Salman Khan  2017           Action
# K         Bhool Bhulaiyaa 2       Kartik Aaryan  2022    Horror Comedy
# L                Brahmastra       Ranbir Kapoor  2022          Fantasy
#
#    BoxOffice(INR Crore)  IMDb  Rank
# ...
