# %%
import pandas as pd
df=pd.read_csv("Data2.csv")
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df=df[df["Year"]>2018]

# %%
df.to_csv("UpdatedData.csv")#with index column

# %%
df.to_csv("UpdatedData2.csv",index=False)#without indexing column

# %%
df.to_excel("Excelfile.xlsx",index=False)

# %%
df1=pd.read_excel("Excelfile.xlsx",sheet_name="Sheet1")
df1
# Out:
#             Actor                      Film  Year          Genre  \
# 0  Shah Rukh Khan                   Pathaan  2023         Action
# 1   Ranbir Kapoor                Brahmastra  2022        Fantasy
# 2  Hrithik Roshan                       War  2019         Action
# 3    Akshay Kumar                Good Newwz  2019         Comedy
# 4   Kartik Aaryan         Bhool Bhulaiyaa 2  2022  Horror Comedy
# 5   Vicky Kaushal  Uri: The Surgical Strike  2019         Action
#
#    BoxOffice(INR Crore)  IMDb
# 0                  1050   7.2
# 1                   431   5.6
# 2                   475   6.5
# 3                   318   7.0
# 4                   266   5.9
# 5                   342   8.2

# %%
with pd.ExcelWriter("Excelfile.xlsx") as file:
    df1.to_excel(file,sheet_name="Data1",index=False)

# %%
df2=pd.read_json("Data.json")

# %%
df2
# Out:
#       user  pages                                            address
# 0  Ashwani     23      {'City': 'Charkhi Dadri', 'Village': 'Mauri'}
# 1   Shikha     24  {'City': 'Charkhi Dadri', 'Village': 'Bageshwa...

# %%
data=[{
        "user": "Ashwani",
        "pages": 23,
        "address":{"City":"Charkhi Dadri","Village":"Mauri"}
    },
    {
        "user":"Shikha",
        "pages": 24,
        "address":{"City":"Charkhi Dadri","Village":"Bageshwari"}
    }]
df3=pd.json_normalize(data)

# %%
df3
# Out:
#       user  pages   address.City address.Village
# 0  Ashwani     23  Charkhi Dadri           Mauri
# 1   Shikha     24  Charkhi Dadri      Bageshwari
