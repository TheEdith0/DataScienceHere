# %%
print(f"{"hello":<10}") #left allignment
print(f"{"hello":>10}") #right allignment
print(f"{"hello":^10}")#centre allignment
# Out:
# hello
#      hello
#   hello

# %%
for i in range(1,8):
    for j in range(1,4):
        print(j,end=" ")
# Out:
# 1 2 3 1 2 3 1 2 3 1 2 3 1 2 3 1 2 3 1 2 3

# %%
a=0
while(a<8):
    print("i am here.")
    a+=1
# Out:
# i am here.
# i am here.
# i am here.
# i am here.
# i am here.
# i am here.
# i am here.
# i am here.

# %%
print("hello")
print("kese ho")
# Out:
# hello
# kese ho

# %%
tup=(10,9,3,8,5,6)
print(sorted(tup))
# Out:
# [3, 5, 6, 8, 9, 10]

# %%
print(tup.index(3))
# Out:
# 2

# %%
print(tup.count(3))
# Out:
# 1

# %%
#packing
person=("Ashwani",20,"DATA SCIENCE")

#UNPACKING
name,age,course=person
print(name)
print(age)
print(course)
# Out:
# Ashwani
# 20
# DATA SCIENCE
