# %%
name="Hyee harry how are you?"

# %%
print(name)
# Out:
# Hyee harry how are you?

# %% [markdown]
# methods

# %%
name.upper()
# Out:
# 'HYEE HARRY HOW ARE YOU?'

# %%
print(name)
# Out:
# Hyee harry how are you?

# %%
name.lower(
    
)
# Out:
# 'hyee harry how are you?'

# %%
name.count("r")
# Out:
# 3

# %%
name.endswith("ry")
# Out:
# False

# %%
name[1]
# Out:
# 'y'

# %%
print(len(name))
# Out:
# 23

# %%
name.replace("harry","Ashvin")
# Out:
# 'Hyee Ashvin how are you?'

# %%
print(name)
# Out:
# Hyee harry how are you?

# %%
print(name.split(" "))
# Out:
# ['Hyee', 'harry', 'how', 'are', 'you?']

# %%
name[1::2]
# Out:
# 'yehryhwaeyu'

# %%
name[0:20:3]
# Out:
# 'Heayoa '
