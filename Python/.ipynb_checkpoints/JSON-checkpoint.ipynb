# %%
import json
data={"Name":"Ashvin","Class":"Btech Cse A","age":20}
json_data=json.dumps(data)
print(json_data)
print(type(json_data))
# Out:
# {"Name": "Ashvin", "Class": "Btech Cse A", "age": 20}
# <class 'str'>

# %%
with open("info.json","w") as file:
    json.dump(data,file)

# %%
with open("info.json","r") as file:
    data2=json.load(file)
print(data2)
# Out:
# {'Name': 'Ashvin', 'Class': 'Btech Cse A', 'age': 20}

# %%
print(type(data2))
# Out:
# <class 'dict'>

# %%
python_data=json.loads(json_data)
print(python_data)
# Out:
# {'Name': 'Ashvin', 'Class': 'Btech Cse A', 'age': 20}

# %%
print(type(python_data))
# Out:
# <class 'dict'>
