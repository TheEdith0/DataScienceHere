# %%
#Empty set
s=set()

# %%
s.update([1,2,3,4,4,5,6])

# %%
s
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s.add(89)
s
# Out:
# {1, 2, 3, 4, 5, 6, 89}

# %%
s.remove(1)#Shows error if element is not found
s
# Out:
# {2, 3, 4, 5, 6, 89}

# %%
s.discard(4)# do not show error when element is not found
s
# Out:
# {2, 3, 5, 6, 89}

# %%
s.pop()#removes random element and return it
# Out:
# 2

# %%
s
# Out:
# {3, 5, 6, 89}

# %%
newset=s.copy()
newset
# Out:
# {3, 5, 6, 89}

# %%
newset.clear()# clear set
newset
# Out:
# set()

# %%
s1=s.copy()
s2=(100,101,99,78,90,5,6)
s3=s1.union(s2)

# %%
s3
# Out:
# {3, 5, 6, 78, 89, 90, 99, 100, 101}

# %%
s4=s1.intersection(s2)
s4
# Out:
# {5, 6}

# %%
s5=s1.difference(s4)
s5
# Out:
# {3, 89}

# %%
s6=s3.symmetric_difference(s1)
s6
# Out:
# {78, 90, 99, 100, 101}

# %%
s4.issubset(s2)
# Out:
# True

# %%
s4.issuperset(s2)
# Out:
# False

# %%
d1={1:"Ashvin",2:'Sujita',3:"Radha",4:"Dharamjeet"}
d1
# Out:
# {1: 'Ashvin', 2: 'Sujita', 3: 'Radha', 4: 'Dharamjeet'}

# %%
d1[1]
# Out:
# 'Ashvin'

# %%
d1.keys()
# Out:
# dict_keys([1, 2, 3, 4])

# %%
d1.values()
# Out:
# dict_values(['Ashvin', 'Sujita', 'Radha', 'Dharamjeet'])

# %%
d1.items()
# Out:
# dict_items([(1, 'Ashvin'), (2, 'Sujita'), (3, 'Radha'), (4, 'Dharamjeet')])

# %%
d1.get(5,"Default value")
# Out:
# 'Default value'

# %%
d2={5:"Bholii",6:"Himanshu",7:"Ayush"}
d3=d1|d2
d3
# Out:
# {1: 'Ashvin',
#  2: 'Sujita',
#  3: 'Radha',
#  4: 'Dharamjeet',
#  5: 'Bholii',
#  6: 'Himanshu',
#  7: 'Ayush'}

# %%
d3.update({8:"Shikha"})
d3
# Out:
# {1: 'Ashvin',
#  2: 'Sujita',
#  3: 'Radha',
#  4: 'Dharamjeet',
#  5: 'Bholii',
#  6: 'Himanshu',
#  7: 'Ayush',
#  8: 'Shikha'}

# %%
d3.pop(5)
# Out:
# 'Bholii'

# %%
d3
# Out:
# {1: 'Ashvin',
#  2: 'Sujita',
#  3: 'Radha',
#  4: 'Dharamjeet',
#  6: 'Himanshu',
#  7: 'Ayush',
#  8: 'Shikha'}

# %%
d3.update({9:"Ashok",10:"Liluuu"})
d3.popitem()#removes and returns last value you inserted
# Out:
# (10, 'Liluuu')

# %%
d3.setdefault(10,"Unknown")
d3
# Out:
# {1: 'Ashvin',
#  2: 'Sujita',
#  3: 'Radha',
#  4: 'Dharamjeet',
#  6: 'Himanshu',
#  7: 'Ayush',
#  8: 'Shikha',
#  9: 'Ashok',
#  10: 'Unknown'}

# %%
d3.setdefault(9,"Unknown")
# Out:
# 'Ashok'

# %%
d3
# Out:
# {1: 'Ashvin',
#  2: 'Sujita',
#  3: 'Radha',
#  4: 'Dharamjeet',
#  6: 'Himanshu',
#  7: 'Ayush',
#  8: 'Shikha',
#  9: 'Ashok',
#  10: 'Unknown'}

# %%
d4=d3.copy()

# %%
d4
# Out:
# {1: 'Ashvin',
#  2: 'Sujita',
#  3: 'Radha',
#  4: 'Dharamjeet',
#  6: 'Himanshu',
#  7: 'Ayush',
#  8: 'Shikha',
#  9: 'Ashok',
#  10: 'Unknown'}

# %%
d4.clear()
d4
# Out:
# {}
