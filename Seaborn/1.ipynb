# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
sns.set_theme(style="darkgrid")

x=np.array([1,12,24,54,65,23,45,80,70, 90,40,50,87])
y=np.sin(x)

sns.lineplot(x=x, y=y)
plt.title('Beautiful Line Plot')
plt.show()
